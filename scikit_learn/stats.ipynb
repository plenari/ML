# %%
from IPython.display import Image

# %% [markdown]
# # 概率
# # 凸优化
# # 梯度
# # 泰勒公式

# %% [markdown]
# 条件概率
# P(a|b)=P(ab)/P(b)
# 全概率公式，在所有bi发生的条件下a 可能发生的概率
# P(a)=sum(P(a|Bi)P(Bi))

# %%
Image('app_byes.jpg')

# %% [markdown]
# 二项分布，n,p。抛硬币n次，p次朝上。

# %%
Image('possion.jpg')

# %% [markdown]
# 指数分布

# %%
Image('exp_play.jpg')

# %% [markdown]
# 指数分布重要特性是无记忆性。

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,10,200)
theta=0.9
y=np.exp(-x/theta)/theta
plt.plot(x,y)
plt.show()

# %%
Image('zhengtai.jpg')

# %%
Image('logstical.jpg')
