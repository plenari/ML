# %%
import numpy as np
from scipy import linalg

# %%
a=np.arange(36).reshape(6,6)
linalg.eig(a.dot(a.T))#特征值，特征向量
# Out:
# (array([  1.48833326e+04 +0.00000000e+00j,
#           2.66674146e+01 +0.00000000e+00j,
#           5.69898646e-13 +0.00000000e+00j,
#          -2.83125331e-14 +6.64401253e-14j,
#          -2.83125331e-14 -6.64401253e-14j,  -2.39095770e-14 +0.00000000e+00j]),
#  array([[-0.05255297+0.j        ,  0.72183635+0.j        ,
#           0.10265574+0.j        , -0.42694537+0.10699567j,
#          -0.42694537-0.10699567j, -0.05684334+0.j        ],
#         [-0.17270437+0.j        ,  0.51518084+0.j        ,
#           0.01618342+0.j        ,  0.06365469-0.32233467j,
#           0.06365469+0.32233467j,  0.32981073+0.j        ],
#         [-0.29285577+0.j        ,  0.30852533+0.j        ,
#           0.10567529+0.j        ,  0.64216882+0.j        ,
#           0.64216882-0.j        , -0.43565582+0.j        ],
#         [-0.41300717+0.j        ,  0.10186983+0.j        ,
#          -0.05975991+0.j        ,  0.04500065+0.23371871j,
#           0.04500065-0.23371871j,  0.44634837+0.j        ],
#         [-0.53315857+0.j        , -0.10478568+0.j        ,
#          -0.77551844+0.j        , -0.13639967+0.28692291j,
#          -0.13639967-0.28692291j, -0.62075553+0.j        ],
#         [-0.65330996+0.j        , -0.31144119+0.j        ,
#           0.61076389+0.j        , -0.18747912-0.30530262j,
#          -0.18747912+0.30530262j,  0.33709558+0.j        ]]))

# %%
m,n=10,10#方针才可以求逆
A=np.random.rand(m,n)
B=np.random.rand(m,1)
x1=linalg.solve(A,B)#solve ax=b,faster
x2=np.dot(linalg.inv(A),B)#x=a-1*b,slower
print(np.allclose(x1,x2))#
# Out:
# True

# %%
#lu 分解
luf=linalg.lu_factor(A)
x3=linalg.lu_solve(luf,B)
np.allclose(x1,x3)
# Out:
# True

# %%
luf[0]
# Out:
# array([[ 0.91275412,  0.09560552,  0.11010108,  0.56210627,  0.34637978,
#          0.17606118,  0.22412628,  0.78497108,  0.01168514,  0.25699744],
#        [ 0.60095305,  0.91151697,  0.31551717, -0.01102429, -0.04309076,
#          0.25569789,  0.63665574,  0.04371735,  0.30041889,  0.69835645],
#        [ 0.30028059,  0.56990109,  0.60827923,  0.4531741 ,  0.58203754,
#          0.73565055,  0.29853602,  0.53300616,  0.58752735, -0.15834597],
#        [ 0.21571811,  0.64734749, -0.08664891,  0.64626791,  0.60283431,
#          0.18163655, -0.11707002,  0.80793211, -0.0964574 , -0.38355618],
#        [ 0.68828944,  0.3705318 ,  0.2221073 , -0.29951744,  0.37222382,
#          0.37193773,  0.02294111,  0.22797388, -0.03618046,  0.14305658],
#        [ 0.67749427,  0.90155728, -0.35250894, -0.09333729,  0.31296118,
#          0.77775212, -0.22054844, -0.18351581,  0.70157673,  0.025862  ],
#        [ 0.90782252,  0.4407692 ,  0.50868597,  0.06216689,  0.22988221,
#         -0.35402351, -0.69846129, -0.64548732,  0.56626131, -0.27760099],
#        [ 0.60958605,  0.24951116,  0.30987484,  0.24359884, -0.81486868,
#          0.02653654, -0.5320578 , -0.79433049,  0.82571856,  0.09990656],
#        [ 0.53616587,  0.61483074,  0.13556586,  0.45370499, -0.90409518,
#         -0.09695268,  0.25614254,  0.55646424, -0.37886847,  0.75503256],
#        [ 0.97078899,  0.56597741,  0.31108889,  0.04773334,  0.39850151,
#         -0.69778058,  0.29909994,  0.24527056, -0.94688851,  0.30915303]])

# %% [markdown]
# ## 最小二乘法
#  ### lstsq,

# %%
linalg.lstsq?

# %% [markdown]
# ## 特征值，eig

# %%
evalues,evector=linalg.eig(A)
evalues,evector
# Out:
# (array([ 4.85019113+0.j        , -0.85525594+0.25374211j,
#         -0.85525594-0.25374211j,  0.60135365+0.13839339j,
#          0.60135365-0.13839339j, -0.26184859+0.47361395j,
#         -0.26184859-0.47361395j,  0.11784676+0.16945834j,
#          0.11784676-0.16945834j, -0.33549878+0.j        ]),
#  array([[-0.32460977+0.j        , -0.35221300-0.00778637j,
#          -0.35221300+0.00778637j, -0.14925715-0.22413299j,
#          -0.14925715+0.22413299j, -0.18188413-0.21182452j,
#          -0.18188413+0.21182452j, -0.19394521-0.00231141j,
#          -0.19394521+0.00231141j, -0.08779841+0.j        ],
#         [-0.27503772+0.j        , -0.11593729+0.08677092j,
#          -0.11593729-0.08677092j,  0.14392424-0.21919268j,
#           0.14392424+0.21919268j,  0.24599174-0.23329836j,
#           0.24599174+0.23329836j, -0.18187449-0.07367534j,
#          -0.18187449+0.07367534j, -0.15627547+0.j        ],
#         [-0.35319343+0.j        ,  0.48269445+0.j        ,
#           0.48269445-0.j        ,  0.52651969+0.j        ,
#           0.52651969-0.j        , -0.02871878+0.25529107j,
#          -0.02871878-0.25529107j,  0.01599545+0.1428024j ,
#           0.01599545-0.1428024j ,  0.08982058+0.j        ],
#         [-0.31140893+0.j        , -0.21039310-0.04365568j,
#          -0.21039310+0.04365568j, -0.21103321+0.02143851j,
#          -0.21103321-0.02143851j,  0.03631053+0.37212099j,
#           0.03631053-0.37212099j, -0.30929815+0.0505278j ,
#          -0.30929815-0.0505278j , -0.21186782+0.j        ],
#         [-0.33247615+0.j        , -0.20514718+0.33749657j,
#          -0.20514718-0.33749657j,  0.06012271-0.02158157j,
#           0.06012271+0.02158157j, -0.51699279+0.j        ,
#          -0.51699279-0.j        , -0.14776944-0.14128219j,
#          -0.14776944+0.14128219j, -0.34869096+0.j        ],
#         [-0.24840427+0.j        ,  0.12936976-0.23830144j,
#           0.12936976+0.23830144j, -0.19762770+0.07847886j,
#          -0.19762770-0.07847886j, -0.12341514-0.06404312j,
#          -0.12341514+0.06404312j, -0.32287368+0.02597717j,
#          -0.32287368-0.02597717j, -0.09882982+0.j        ],
#         [-0.21889234+0.j        ,  0.24792624-0.05379599j,
#           0.24792624+0.05379599j, -0.45271775-0.02809143j,
#          -0.45271775+0.02809143j, -0.07685071+0.2743633j ,
#          -0.07685071-0.2743633j , -0.16010901+0.05944795j,
#          -0.16010901-0.05944795j, -0.45362055+0.j        ],
#         [-0.27880620+0.j        ,  0.12899821+0.13743572j,
#           0.12899821-0.13743572j,  0.01907045+0.17302704j,
#           0.01907045-0.17302704j,  0.30706147-0.25297366j,
#           0.30706147+0.25297366j,  0.53660432+0.j        ,
#           0.53660432-0.j        ,  0.63173470+0.j        ],
#         [-0.40842381+0.j        , -0.29224100-0.07219558j,
#          -0.29224100+0.07219558j,  0.37964987+0.32368883j,
#           0.37964987-0.32368883j,  0.24026186-0.10014601j,
#           0.24026186+0.10014601j,  0.53286494+0.06107237j,
#           0.53286494-0.06107237j,  0.17979270+0.j        ],
#         [-0.36408762+0.j        ,  0.36640912-0.14653706j,
#           0.36640912+0.14653706j,  0.04202855-0.02222442j,
#           0.04202855+0.02222442j, -0.04040220+0.07650055j,
#          -0.04040220-0.07650055j,  0.21026111-0.09638616j,
#           0.21026111+0.09638616j,  0.38259016+0.j        ]]))

# %% [markdown]
# ## 奇异值分解，svd ,linalg.svd
# #### 提取有用信息，可以按照用无用信息提取

# %%
from scipy.misc import imread
r,g,b=np.rollaxis(imread('CD28.jpg'),2).astype(float)
img=0.2829*r+0.5870*g+0.1140*b
img.shape
# Out:
# (2880, 2912)

# %%
U,s,Vh=linalg.svd(img)
U.shape,s.shape,Vh.shape
# Out:
# ((2880, 2880), (2880,), (2912, 2912))

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(s,lw=3)
plt.show()

# %% [markdown]
# #### 一共有2000个特征，可是只有前边几个有用，后边的效果很不明显。
# #### U*s*Vh

# %%
def composite(U,s,Vh,n):
    return np.dot(U[:,:n],s[:n,np.newaxis]*Vh[:n,:])#怎么想乘的呢？

# %%
np.allclose(img,composite(U,s,Vh,len(s)))
# Out:
# True

# %%
img5=composite(U,s,Vh,5)
img50=composite(U,s,Vh,50)
img100=composite(U,s,Vh,100)
plt.imshow(img)
plt.show()
plt.imshow(img5)
plt.show()
plt.imshow(img50)
plt.show()

# %%
plt.imshow(img100)
plt.show()

# %%
img50.shape
# Out:
# (2880, 2912)

# %% [markdown]
# ### 统计-stats

# %%
from scipy.stats import norm

# %% [markdown]
# 它包含四类常用的函数：
#
# - `norm.cdf` 返回对应的[累计分布函数](https://zh.wikipedia.org/wiki/%E7%B4%AF%E7%A7%AF%E5%88%86%E5%B8%83%E5%87%BD%E6%95%B0)值
# - `norm.pdf` 返回对应的[概率密度函数](https://zh.wikipedia.org/wiki/%E6%A9%9F%E7%8E%87%E5%AF%86%E5%BA%A6%E5%87%BD%E6%95%B8)值
# - `norm.rvs` 产生指定参数的随机变量
# - `norm.fit` 返回给定数据下，各参数的[最大似然估计](https://zh.wikipedia.org/wiki/%E6%9C%80%E5%A4%A7%E4%BC%BC%E7%84%B6%E4%BC%B0%E8%AE%A1)（MLE）值
#
# 从正态分布产生500个随机点：

# %%
x=norm.rvs(size=500)
type(x)
# Out:
# numpy.ndarray

# %%
h=plt.hist(x)

# %%
h=plt.hist(x,normed=True,bins=20)

# %%
x_mean,x_std=norm.fit(x)
x_mean,x_std
# Out:
# (-0.054907262056195977, 0.97876318777774007)

# %%
h=plt.hist(x,normed=True,bins=20)
xx=np.linspace(-3,3,100)
p=plt.plot(xx,norm.pdf(xx),'r-')

# %% [markdown]
# ### 不定积分

# %%
from scipy.integrate import trapz

# %%
p=trapz(norm.pdf(xx),xx)
p
# Out:
# 0.99729206762692424

# %%
plt.fill_between(xx, norm.pdf(xx), color = 'red')

# %%
x=np.linspace(-5,5,100)
p = plt.plot(x, norm.pdf(x, loc=0, scale=1))
p = plt.plot(x, norm.pdf(x, loc=0.5, scale=2))
p = plt.plot(x, norm.pdf(x, loc=-0.5, scale=.5))

# %% [markdown]
# ### 其他连续分布

# %%
from scipy.stats import lognorm, t, dweibull
#对数正态分布，t分布，韦氏分布

# %%
 x = np.linspace(0.01, 3, 100)
 
plt.plot(x, dweibull.pdf(x, 1), label='s=1, constant failure rate')
plt.plot(x, dweibull.pdf(x, 2), label='s>1, increasing failure rate')
plt.plot(x, dweibull.pdf(x, .1), label='0<s<1, decreasing failure rate')
plt.legend() 
plt.show()

# %%
x = np.linspace(-3, 3, 100)

plt.plot(x, t.pdf(x, 1), label='df=1')
plt.plot(x, t.pdf(x, 2), label='df=2')
plt.plot(x, t.pdf(x, 100), label='df=100')
plt.plot(x[::5], norm.pdf(x[::5]), 'kx', label='normal')
plt.legend()
plt.show()

# %% [markdown]
# ### 离散分布

# %%
from scipy.stats import binom, poisson, randint
#二项分布，泊松分布，随机数

# %%
#二项分布
num_trials = 60
x = np.arange(num_trials)

plt.plot(x, binom(num_trials, 0.5).pmf(x), 'o-', label='p=0.5')
plt.plot(x, binom(num_trials, 0.2).pmf(x), 'o-', label='p=0.2')
plt.legend()
plt.show()

# %% [markdown]
# ### 自定义离散分布
# 导入函数

# %%
from scipy.stats import rv_discrete
xk=[1,2,3,4,5,6]
pk=[0.3,0.35,0.25,0.05,0.025,0.025]

# %%
loaded=rv_discrete(values=(xk,pk))
loaded.rvs(size=2)
# Out:
# array([3, 5])

# %%
rv_y=loaded.rvs(size=100)
plt.hist(rv_y)
plt.show()

# %% [markdown]
# ### 假设检验
