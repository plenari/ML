# %% [raw]
# 1，一维插值
# interpld(x,y),先导入一维插值函数 interp1d
# 我们可以通过 kind 参数来调节使用的插值方法，来得到不同的结果：
# nearest 最近邻插值
# zero 0阶插值
# linear 线性插值
# quadratic 二次插值
# cubic 三次插值
# 4,5,6,7 更高阶插值
# 例如：
# cp_ch4 = interp1d(data['TK'], data['Cp'], kind="nearest")
#
# 以上方法很少用到。
# 2，二维插值
# interp2d,interpnd
# 多维度的插值
#
# 3，基向插值
#
# from scipy.interpolate.rbf import Rbf
# 核心=gaussian,nverse_multiquadric,
#
# cp_rbf = Rbf(data['TK'], data['Cp'], function = "multiquadric")
#
# 4,RBF
# from mpl_toolkits.mplot3d import Axes3D
#
# 一，统计学方法，
# 有很多统计方法
# import scipy.stats.stats as st
# 1，正态分布
# from scipy.stats import norm
# 它包含四类常用的函数：
#
# norm.cdf 返回对应的累计分布函数值
# norm.pdf 返回对应的概率密度函数值
# norm.rvs 产生指定参数的随机变量
# norm.fit 返回给定数据下，各参数的最大似然估计（MLE）值
# p = plot(x, norm(loc=0, scale=1).pdf(x))
#
# 二，曲线拟合
#
# from numpy import polyfit, poly1d
#
# coeff = polyfit(x, noise_y, 1)
#
# 一阶多项式 y=a1x+a0y=a1x+a0 拟合，返回两个系数 [a1,a0][a1,a0]。
#
# f = poly1d(coeff)
#
#
# 2，最小而成拟合
#
# from scipy.linalg import lstsq 最小二乘法
# from scipy.stats import linregress 线性回归
# 3，更高级的拟合
#
# from scipy.optimize import curve_fit
# p_est, err_est = curve_fit(function, x, y_noisy)
